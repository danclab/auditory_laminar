# %%
import mne
import numpy as np
import matplotlib.pyplot

# %% [markdown]
# # Oddball Task

# %% [markdown]
# ## Standards

# %%
epochs=mne.read_epochs('/home/casalab/Desktop/CF/MEG_data/data/derivatives/processed/sub-001/ses-01/sub-001-ses-01-001-standards-epo.fif')
epochs_standards=epochs.average()
fig=epochs_standards.plot_joint()
# Out:
# Reading /home/casalab/Desktop/CF/MEG_data/data/derivatives/processed/sub-001/ses-01/sub-001-ses-01-001-standards-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =    -200.00 ...     500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 576 matching events found
# No baseline correction applied
# 0 projection items activated
# No projector specified for this dataset. Please consider the method self.add_proj.
# Removing 5 compensators from info because not all compensation channels were picked.
# Removing 5 compensators from info because not all compensation channels were picked.
# Removing 5 compensators from info because not all compensation channels were picked.
# Removing 5 compensators from info because not all compensation channels were picked.

# %%
epochs=mne.read_epochs('/home/casalab/Desktop/CF/MEG_data/data/derivatives/processed/sub-001/ses-01/sub-001-ses-01-002-standards-epo.fif')
epochs_standards=epochs.average()
fig=epochs_standards.plot_joint()
# Out:
# Reading /home/casalab/Desktop/CF/MEG_data/data/derivatives/processed/sub-001/ses-01/sub-001-ses-01-002-standards-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =    -200.00 ...     500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 576 matching events found
# No baseline correction applied
# 0 projection items activated
# No projector specified for this dataset. Please consider the method self.add_proj.
# Removing 5 compensators from info because not all compensation channels were picked.
# Removing 5 compensators from info because not all compensation channels were picked.
# Removing 5 compensators from info because not all compensation channels were picked.
# Removing 5 compensators from info because not all compensation channels were picked.

# %% [markdown]
# ## Deviants

# %%
epochs=mne.read_epochs('/home/casalab/Desktop/CF/MEG_data/data/derivatives/processed/sub-001/ses-01/sub-001-ses-01-001-deviants-epo.fif')
epochs_deviants=epochs.average()
fig=epochs_deviants.plot_joint()
# Out:
# Reading /home/casalab/Desktop/CF/MEG_data/data/derivatives/processed/sub-001/ses-01/sub-001-ses-01-001-deviants-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =    -200.00 ...     500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 72 matching events found
# No baseline correction applied
# 0 projection items activated
# No projector specified for this dataset. Please consider the method self.add_proj.
# Removing 5 compensators from info because not all compensation channels were picked.
# Removing 5 compensators from info because not all compensation channels were picked.
# Removing 5 compensators from info because not all compensation channels were picked.
# Removing 5 compensators from info because not all compensation channels were picked.

# %%
epochs=mne.read_epochs('/home/casalab/Desktop/CF/MEG_data/data/derivatives/processed/sub-001/ses-01/sub-001-ses-01-002-deviants-epo.fif')
epochs_deviants=epochs.average()
fig=epochs_deviants.plot_joint()
# Out:
# Reading /home/casalab/Desktop/CF/MEG_data/data/derivatives/processed/sub-001/ses-01/sub-001-ses-01-002-deviants-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =    -200.00 ...     500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 72 matching events found
# No baseline correction applied
# 0 projection items activated
# No projector specified for this dataset. Please consider the method self.add_proj.
# Removing 5 compensators from info because not all compensation channels were picked.
# Removing 5 compensators from info because not all compensation channels were picked.
# Removing 5 compensators from info because not all compensation channels were picked.
# Removing 5 compensators from info because not all compensation channels were picked.

# %% [markdown]
# # Masker Task

# %% [markdown]
# ## Undetected

# %%
epochs=mne.read_epochs('/home/casalab/Desktop/CF/MEG_data/data/derivatives/processed/sub-001/ses-01/sub-001-ses-01-003-undetected-epo.fif')
epochs_undetected=epochs.average()
fig=epochs_undetected.plot_joint()
# Out:
# Reading /home/casalab/Desktop/CF/MEG_data/data/derivatives/processed/sub-001/ses-01/sub-001-ses-01-003-undetected-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =    -200.00 ...     500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 276 matching events found
# No baseline correction applied
# 0 projection items activated
# No projector specified for this dataset. Please consider the method self.add_proj.
# Removing 5 compensators from info because not all compensation channels were picked.
# Removing 5 compensators from info because not all compensation channels were picked.
# Removing 5 compensators from info because not all compensation channels were picked.
# Removing 5 compensators from info because not all compensation channels were picked.

# %%
epochs=mne.read_epochs('/home/casalab/Desktop/CF/MEG_data/data/derivatives/processed/sub-001/ses-01/sub-001-ses-01-004-undetected-epo.fif')
epochs_undetected=epochs.average()
fig=epochs_undetected.plot_joint()
# Out:
# Reading /home/casalab/Desktop/CF/MEG_data/data/derivatives/processed/sub-001/ses-01/sub-001-ses-01-004-undetected-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =    -200.00 ...     500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 316 matching events found
# No baseline correction applied
# 0 projection items activated
# No projector specified for this dataset. Please consider the method self.add_proj.
# Removing 5 compensators from info because not all compensation channels were picked.
# Removing 5 compensators from info because not all compensation channels were picked.
# Removing 5 compensators from info because not all compensation channels were picked.
# Removing 5 compensators from info because not all compensation channels were picked.

# %% [markdown]
# ## Detected

# %%
epochs=mne.read_epochs('/home/casalab/Desktop/CF/MEG_data/data/derivatives/processed/sub-001/ses-01/sub-001-ses-01-003-detected-epo.fif')
epochs_detected=epochs.average()
fig=epochs_detected.plot_joint()
# Out:
# Reading /home/casalab/Desktop/CF/MEG_data/data/derivatives/processed/sub-001/ses-01/sub-001-ses-01-003-detected-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =    -200.00 ...     500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 282 matching events found
# No baseline correction applied
# 0 projection items activated
# No projector specified for this dataset. Please consider the method self.add_proj.
# Removing 5 compensators from info because not all compensation channels were picked.
# Removing 5 compensators from info because not all compensation channels were picked.
# Removing 5 compensators from info because not all compensation channels were picked.
# Removing 5 compensators from info because not all compensation channels were picked.

# %%
epochs=mne.read_epochs('/home/casalab/Desktop/CF/MEG_data/data/derivatives/processed/sub-001/ses-01/sub-001-ses-01-004-detected-epo.fif')
epochs_detected=epochs.average()
fig=epochs_detected.plot_joint()
# Out:
# Reading /home/casalab/Desktop/CF/MEG_data/data/derivatives/processed/sub-001/ses-01/sub-001-ses-01-004-detected-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =    -200.00 ...     500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 332 matching events found
# No baseline correction applied
# 0 projection items activated
# No projector specified for this dataset. Please consider the method self.add_proj.
# Removing 5 compensators from info because not all compensation channels were picked.
# Removing 5 compensators from info because not all compensation channels were picked.
# Removing 5 compensators from info because not all compensation channels were picked.
# Removing 5 compensators from info because not all compensation channels were picked.
