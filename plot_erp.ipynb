# %%
import mne
import numpy as np
import matplotlib.pyplot

# %%
epochs=mne.read_epochs('/home/common/bonaiuto/auditory_laminar/derivatives/processed/sub-001/ses-01/autoreject-sub-001-ses-01-001-btn_trial-epo.fif')
btn=epochs.average()
fig1=btn.plot_joint()
# Out:
# Reading /home/common/bonaiuto/auditory_laminar/derivatives/processed/sub-001/ses-01/autoreject-sub-001-ses-01-001-btn_trial-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# Not setting metadata
# 71 matching events found
# No baseline correction applied
# 0 projection items activated
# No projector specified for this dataset. Please consider the method self.add_proj.
# Removing 5 compensators from info because not all compensation channels were picked.
# Removing 5 compensators from info because not all compensation channels were picked.
# Removing 5 compensators from info because not all compensation channels were picked.
# Removing 5 compensators from info because not all compensation channels were picked.

# %%
epochs=mne.read_epochs('/home/common/bonaiuto/auditory_laminar/derivatives/processed/sub-001/ses-01/autoreject-sub-001-ses-01-002-btn_trial-epo.fif')
btn=epochs.average()
fig1=btn.plot_joint()
# Out:
# Reading /home/common/bonaiuto/auditory_laminar/derivatives/processed/sub-001/ses-01/autoreject-sub-001-ses-01-002-btn_trial-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# Not setting metadata
# 64 matching events found
# No baseline correction applied
# 0 projection items activated
# No projector specified for this dataset. Please consider the method self.add_proj.
# Removing 5 compensators from info because not all compensation channels were picked.
# Removing 5 compensators from info because not all compensation channels were picked.
# Removing 5 compensators from info because not all compensation channels were picked.
# Removing 5 compensators from info because not all compensation channels were picked.

# %%
epochs=mne.read_epochs('/home/common/bonaiuto/auditory_laminar/derivatives/processed/sub-001/ses-01/autoreject-sub-001-ses-01-003-btn_trial-epo.fif')
btn=epochs.average()
fig1=btn.plot_joint()
# Out:
# Reading /home/common/bonaiuto/auditory_laminar/derivatives/processed/sub-001/ses-01/autoreject-sub-001-ses-01-003-btn_trial-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# Not setting metadata
# 82 matching events found
# No baseline correction applied
# 0 projection items activated
# No projector specified for this dataset. Please consider the method self.add_proj.
# Removing 5 compensators from info because not all compensation channels were picked.
# Removing 5 compensators from info because not all compensation channels were picked.
# Removing 5 compensators from info because not all compensation channels were picked.
# Removing 5 compensators from info because not all compensation channels were picked.

# %%
epochs=mne.read_epochs('/home/common/bonaiuto/auditory_laminar/derivatives/processed/sub-001/ses-01/autoreject-sub-001-ses-01-004-btn_trial-epo.fif')
btn=epochs.average()
fig1=btn.plot_joint()
# Out:
# Reading /home/common/bonaiuto/auditory_laminar/derivatives/processed/sub-001/ses-01/autoreject-sub-001-ses-01-004-btn_trial-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# Not setting metadata
# 95 matching events found
# No baseline correction applied
# 0 projection items activated
# No projector specified for this dataset. Please consider the method self.add_proj.
# Removing 5 compensators from info because not all compensation channels were picked.
# Removing 5 compensators from info because not all compensation channels were picked.
# Removing 5 compensators from info because not all compensation channels were picked.
# Removing 5 compensators from info because not all compensation channels were picked.

# %%
epochs=mne.read_epochs('/home/common/bonaiuto/auditory_laminar/derivatives/processed/sub-001/ses-01/autoreject-sub-001-ses-01-003-btn_detect-epo.fif')
btn=epochs.average()
fig1=btn.plot_joint()
# Out:
# Reading /home/common/bonaiuto/auditory_laminar/derivatives/processed/sub-001/ses-01/autoreject-sub-001-ses-01-003-btn_detect-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# Not setting metadata
# 44 matching events found
# No baseline correction applied
# 0 projection items activated
# No projector specified for this dataset. Please consider the method self.add_proj.
# Removing 5 compensators from info because not all compensation channels were picked.
# Removing 5 compensators from info because not all compensation channels were picked.
# Removing 5 compensators from info because not all compensation channels were picked.
# Removing 5 compensators from info because not all compensation channels were picked.

# %%
epochs=mne.read_epochs('/home/common/bonaiuto/auditory_laminar/derivatives/processed/sub-001/ses-01/autoreject-sub-001-ses-01-004-btn_detect-epo.fif')
btn=epochs.average()
fig1=btn.plot_joint()
# Out:
# Reading /home/common/bonaiuto/auditory_laminar/derivatives/processed/sub-001/ses-01/autoreject-sub-001-ses-01-004-btn_detect-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =    -500.00 ...     500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# No projector specified for this dataset. Please consider the method self.add_proj.
# Removing 5 compensators from info because not all compensation channels were picked.
# Removing 5 compensators from info because not all compensation channels were picked.
# Removing 5 compensators from info because not all compensation channels were picked.
# Removing 5 compensators from info because not all compensation channels were picked.
